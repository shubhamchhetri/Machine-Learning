# %%
import pandas as pd

# %%
gosales=pd.read_csv('C:/Users/shubham.chhetri/Desktop/MYPROJECT/Machine learning/Preparing data for ML/GoSales_Tx_LogisticRegression.csv')

# %%
gosales
# Out:
#        IS_TENT GENDER  AGE MARITAL_STATUS    PROFESSION
# 0        False      M   27         Single  Professional
# 1        False      F   39        Married         Other
# 2        False      F   39        Married         Other
# 3        False      F   56    Unspecified   Hospitality
# 4        False      M   45        Married       Retired
# ...        ...    ...  ...            ...           ...
# 60247     True      M   24         Single  Professional
# 60248    False      M   24         Single  Professional
# 60249    False      F   27        Married        Retail
# 60250    False      F   20         Single         Other
# 60251    False      F   37        Married         Other
#
# [60252 rows x 5 columns]

# %%
gosales.shape
# Out:
# (60252, 5)

# %%
gosales.AGE.describe()
# Out:
# count    60252.000000
# mean        34.187479
# std         10.105477
# min         17.000000
# 25%         26.000000
# 50%         33.000000
# 75%         41.000000
# max         69.000000
# Name: AGE, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,7))
pd.value_counts(gosales['IS_TENT']).plot.bar()
plt.show()

# %%
plt.figure(figsize=(10,7))
pd.value_counts(gosales['MARITAL_STATUS']).plot.bar()
plt.show()

# %%
plt.figure(figsize=(10,7))
pd.value_counts(gosales['GENDER']).plot.bar()
plt.show()

# %%
plt.figure(figsize=(10,7))
pd.value_counts(gosales['PROFESSION']).plot.bar()
plt.show()

# %% [markdown]
# Label Encoding

# %%
gender=['M','F']

# %%
from sklearn import preprocessing
label_encoding=preprocessing.LabelEncoder()
label_encoding=label_encoding.fit(gender)

# %%
gosales['GENDER']=label_encoding.transform(gosales['GENDER'].astype(str))

# %%
label_encoding.classes_
# Out:
# array(['F', 'M'], dtype='<U1')

# %%
gosales.sample(10)
# Out:
#        IS_TENT  GENDER  AGE MARITAL_STATUS    PROFESSION
# 22881    False       0   27         Single         Other
# 36550    False       0   34        Married         Other
# 52373    False       1   43        Married  Professional
# 50625    False       0   26         Single         Other
# 24062    False       0   30        Married         Other
# 41861    False       1   33        Married         Sales
# 13903    False       0   65    Unspecified   Hospitality
# 35018    False       1   51        Married  Professional
# 13531    False       0   27         Single       Student
# 54166    False       0   32    Unspecified         Other

# %% [markdown]
# One hot encoding

# %%
gosales=pd.get_dummies(gosales,columns=['MARITAL_STATUS'])

# %%
gosales.sample(10)
# Out:
#        IS_TENT  GENDER  AGE    PROFESSION  MARITAL_STATUS_Married  \
# 34997     True       0   23         Other                       0
# 4517     False       0   39  Professional                       0
# 20202    False       1   32         Other                       0
# 45732     True       1   30         Other                       1
# 51404    False       0   36  Professional                       0
# 9036     False       0   30     Executive                       1
# 31432    False       0   20         Other                       0
# 6745     False       0   28         Other                       0
# 8106     False       0   32         Other                       1
# 29389    False       0   68       Retired                       1
#
#        MARITAL_STATUS_Single  MARITAL_STATUS_Unspecified
# 34997                      1                           0
# 4517                       1                           0
# 20202                      1                           0
# 45732                      0                           0
# 51404                      0                           1
# 9036                       0                           0
# 31432                      1                           0
# 6745                       1                           0
# 8106                       0                           0
# 29389                      0                           0

# %%
gosales=pd.get_dummies(gosales)

# %%
gosales.sample(10)
# Out:
#        IS_TENT  GENDER  AGE  MARITAL_STATUS_Married  MARITAL_STATUS_Single  \
# 25202    False       1   24                       0                      1
# 12441    False       0   41                       1                      0
# 57622    False       1   29                       0                      1
# 27385    False       1   21                       0                      1
# 1914      True       0   26                       1                      0
# 49011    False       0   34                       1                      0
# 41793    False       0   28                       0                      1
# 5961     False       0   47                       0                      0
# 38984    False       0   36                       1                      0
# 11258    False       1   41                       1                      0
#
#        MARITAL_STATUS_Unspecified  PROFESSION_Executive  \
# 25202                           0                     0
# 12441                           0                     0
# 57622                           0                     0
# 27385                           0                     0
# 1914                            0                     0
# 49011                           0                     0
# 41793                           0                     0
# 5961                            1                     0
# 38984                           0                     0
# 11258                           0                     0
#
#        PROFESSION_Hospitality  PROFESSION_Other  PROFESSION_Professional  \
# 25202                       0                 0                        0
# 12441                       1                 0                        0
# 57622                       0                 0                        1
# 27385                       0                 1                        0
# 1914                        0                 1                        0
# 49011                       0                 1                        0
# 41793                       0                 0                        0
# 5961                        1                 0                        0
# 38984                       0                 1                        0
# 11258                       0                 1                        0
#
#        PROFESSION_Retail  PROFESSION_Retired  PROFESSION_Sales  \
# 25202                  0                   0                 0
# 12441                  0                   0                 0
# 57622                  0                   0                 0
# 27385                  0                   0                 0
# 1914                   0                   0                 0
# 49011                  0                   0                 0
# 41793                  0                   0                 0
# 5961                   0                   0                 0
# 38984                  0                   0                 0
# 11258                  0                   0                 0
#
#        PROFESSION_Student  PROFESSION_Trades
# 25202                   1                  0
# 12441                   0                  0
# 57622                   0                  0
# 27385                   0                  0
# 1914                    0                  0
# 49011                   0                  0
# 41793                   1                  0
# 5961                    0                  0
# 38984                   0                  0
# 11258                   0                  0
